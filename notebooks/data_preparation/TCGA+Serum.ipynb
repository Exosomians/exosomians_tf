# %%
import os
os.chdir("../../")

# %%
import exoNet
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./Data/7_DesignMat_SS_Kmer_DB_ForgiAnnot_Label.csv')
data.head()
# Out:
#                          id   chr strand  \
# 0  chr1_100038134_100038156  chr1      +
# 1  chr1_100038169_100038188  chr1      +
# 2  chr1_100088027_100088063  chr1      -
# 3  chr1_100145722_100145741  chr1      -
# 4  chr1_100847023_100847041  chr1      -
#
#                                      seq  length   a   c   g  u    ic  ...  \
# 0                CUCGCCGAGCCGGGCCGUCAUCA      23   3  10   7  3    47  ...
# 1                   GAUCGACGACCCCGGACGGC      20   4   8   7  1    32  ...
# 2  CUCGACACUACGGGUGGACAAAUGGACUCUGUAAAGU      37  11   8  10  8  3836  ...
# 3                   UUCGAUAGCACGGGUUGUUU      20   3   3   6  8    82  ...
# 4                    ACUCUACAACCCAAUUCAU      19   7   7   0  5    75  ...
#
#    D00735.002                         element_string  fiveprime  threeprime  \
# 0   -0.143559                fffssshhhhhhssstttttttt          1           1
# 1    0.018000                   ffsssisshhhhssiissst          1           1
# ...

# %%
data_columns = data.columns

# %%
seq_columns = ['seq', 'DB', 'element_string']
fcn_columns = [column for column in data_columns if not column in seq_columns]
